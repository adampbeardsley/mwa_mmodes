# %%
# %matplotlib notebook
from matplotlib.pyplot import *
import numpy as np
import pyuvdata

# %%
UV = pyuvdata.UVData()
UV.read_uvfits('/data4/beards/MWA/mmodes/data/1220437672_063-066.uvfits')
# Out:
# Required Antenna frame keyword not set, setting to ????
# telescope_location is not set. Using known values for MWA.
# ...

# %%
print UV.data_array.shape
# Out:
# (247680, 1, 128, 4)

# %%
print np.std(UV.data_array)
# Out:
# 4280.5986

# %%
figure()
for i in np.arange(UV.Nblts):
    if UV.ant_1_array[i] == UV.ant_2_array[i]:
        plot(np.abs(UV.data_array[i,0,:,0]),label=UV.antenna_names)
# Out:
# <img src="data:image/png;base64,..." width="640">
